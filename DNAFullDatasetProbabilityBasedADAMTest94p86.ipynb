# %% [markdown]
# <a href="https://colab.research.google.com/github/preritt/Embed/blob/master/DNAFullDatasetProbabilityBasedADAMTest94p86.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import OneHotEncoder
# %matplotlib inline
import tensorflow as tf

# %%
# Load data
train_data = np.load('X_train.npy')
train_label = np.load('y_train.npy')
validation_data = np.load('X_validation.npy')
validation_label = np.load('y_validation.npy')
test_data = np.load('X_test.npy')
test_label = np.load('y_test.npy')

# %%
train_valid_combined = np.concatenate((train_data, validation_data))
train_valid_label = np.concatenate((train_label, validation_label))

# %%
clf = MLPClassifier(hidden_layer_sizes=(90, 90, ), max_iter=500, alpha=1e-4,
                    solver='sgd', verbose=10, tol=1e-5, random_state=1,
                    learning_rate_init=.01)


clf.fit(train_data, train_label)
# Out:
# Iteration 1, loss = 1.03441892
# Iteration 2, loss = 0.96751879
# Iteration 3, loss = 0.89481536
# Iteration 4, loss = 0.81368383
# Iteration 5, loss = 0.72594009
# Iteration 6, loss = 0.62960819
# Iteration 7, loss = 0.53159777
# Iteration 8, loss = 0.44207953
# Iteration 9, loss = 0.36875904
# Iteration 10, loss = 0.30941327
# Iteration 11, loss = 0.26372269
# Iteration 12, loss = 0.22978500
# Iteration 13, loss = 0.20470826
# Iteration 14, loss = 0.18264284
# Iteration 15, loss = 0.16710243
# Iteration 16, loss = 0.15202973
# Iteration 17, loss = 0.14087234
# Iteration 18, loss = 0.12987301
# Iteration 19, loss = 0.12084526
# Iteration 20, loss = 0.11283789
# Iteration 21, loss = 0.10572119
# Iteration 22, loss = 0.09954791
# Iteration 23, loss = 0.09360503
# Iteration 24, loss = 0.08786305
# Iteration 25, loss = 0.08276471
# Iteration 26, loss = 0.07907322
# Iteration 27, loss = 0.07454680
# Iteration 28, loss = 0.07094251
# Iteration 29, loss = 0.06643735
# Iteration 30, loss = 0.06354301
# Iteration 31, loss = 0.06049116
# Iteration 32, loss = 0.05714675
# Iteration 33, loss = 0.05428949
# Iteration 34, loss = 0.05201639
# Iteration 35, loss = 0.04929848
# Iteration 36, loss = 0.04695626
# Iteration 37, loss = 0.04462253
# Iteration 38, loss = 0.04264600
# Iteration 39, loss = 0.04074367
# Iteration 40, loss = 0.03876653
# Iteration 41, loss = 0.03721490
# Iteration 42, loss = 0.03558347
# Iteration 43, loss = 0.03401367
# Iteration 44, loss = 0.03249877
# Iteration 45, loss = 0.03112571
# Iteration 46, loss = 0.02988303
# Iteration 47, loss = 0.02856886
# Iteration 48, loss = 0.02754688
# Iteration 49, loss = 0.02664928
# Iteration 50, loss = 0.02542575
# Iteration 51, loss = 0.02452278
# Iteration 52, loss = 0.02353043
# Iteration 53, loss = 0.02274083
# Iteration 54, loss = 0.02179373
# Iteration 55, loss = 0.02120700
# Iteration 56, loss = 0.02035052
# Iteration 57, loss = 0.01987453
# Iteration 58, loss = 0.01911663
# Iteration 59, loss = 0.01850667
# Iteration 60, loss = 0.01787181
# Iteration 61, loss = 0.01726645
# Iteration 62, loss = 0.01679903
# Iteration 63, loss = 0.01628870
# Iteration 64, loss = 0.01568983
# Iteration 65, loss = 0.01534314
# Iteration 66, loss = 0.01484299
# Iteration 67, loss = 0.01444003
# Iteration 68, loss = 0.01400270
# Iteration 69, loss = 0.01361595
# Iteration 70, loss = 0.01323532
# Iteration 71, loss = 0.01292718
# Iteration 72, loss = 0.01255229
# Iteration 73, loss = 0.01220949
# Iteration 74, loss = 0.01199130
# Iteration 75, loss = 0.01166433
# Iteration 76, loss = 0.01131439
# Iteration 77, loss = 0.01108961
# Iteration 78, loss = 0.01078926
# Iteration 79, loss = 0.01053962
# Iteration 80, loss = 0.01029136
# Iteration 81, loss = 0.01006532
# Iteration 82, loss = 0.00991353
# Iteration 83, loss = 0.00966965
# Iteration 84, loss = 0.00943411
# Iteration 85, loss = 0.00921045
# Iteration 86, loss = 0.00902006
# Iteration 87, loss = 0.00882366
# Iteration 88, loss = 0.00863188
# Iteration 89, loss = 0.00848120
# Iteration 90, loss = 0.00827429
# Iteration 91, loss = 0.00812448
# Iteration 92, loss = 0.00796667
# Iteration 93, loss = 0.00781011
# Iteration 94, loss = 0.00767198
# Iteration 95, loss = 0.00754123
# Iteration 96, loss = 0.00736818
# Iteration 97, loss = 0.00727981
# Iteration 98, loss = 0.00711821
# Iteration 99, loss = 0.00701893
# Iteration 100, loss = 0.00689620
# Iteration 101, loss = 0.00672796
# Iteration 102, loss = 0.00662375
# Iteration 103, loss = 0.00649484
# Iteration 104, loss = 0.00639288
# Iteration 105, loss = 0.00627893
# Iteration 106, loss = 0.00617993
# Iteration 107, loss = 0.00608084
# Iteration 108, loss = 0.00597878
# Iteration 109, loss = 0.00588547
# Iteration 110, loss = 0.00579335
# Iteration 111, loss = 0.00569472
# Iteration 112, loss = 0.00560655
# Iteration 113, loss = 0.00552249
# Iteration 114, loss = 0.00544523
# Iteration 115, loss = 0.00536155
# Iteration 116, loss = 0.00528037
# Iteration 117, loss = 0.00520956
# Iteration 118, loss = 0.00513433
# Iteration 119, loss = 0.00504800
# Iteration 120, loss = 0.00498528
# Iteration 121, loss = 0.00492681
# Iteration 122, loss = 0.00485214
# Iteration 123, loss = 0.00478869
# Iteration 124, loss = 0.00471254
# Iteration 125, loss = 0.00464963
# Iteration 126, loss = 0.00458029
# Iteration 127, loss = 0.00453048
# Iteration 128, loss = 0.00447036
# Iteration 129, loss = 0.00440211
# Iteration 130, loss = 0.00436583
# Iteration 131, loss = 0.00430409
# Iteration 132, loss = 0.00423661
# Iteration 133, loss = 0.00418192
# Iteration 134, loss = 0.00413634
# Iteration 135, loss = 0.00408881
# Iteration 136, loss = 0.00403684
# Iteration 137, loss = 0.00398786
# Iteration 138, loss = 0.00393459
# Iteration 139, loss = 0.00388950
# Iteration 140, loss = 0.00384361
# Iteration 141, loss = 0.00380416
# Iteration 142, loss = 0.00376977
# Iteration 143, loss = 0.00371208
# Iteration 144, loss = 0.00367927
# Iteration 145, loss = 0.00363191
# Iteration 146, loss = 0.00359230
# Iteration 147, loss = 0.00355187
# Iteration 148, loss = 0.00351506
# Iteration 149, loss = 0.00346859
# Iteration 150, loss = 0.00343842
# Iteration 151, loss = 0.00339624
# Iteration 152, loss = 0.00335906
# Iteration 153, loss = 0.00332538
# Iteration 154, loss = 0.00329511
# Iteration 155, loss = 0.00325617
# Iteration 156, loss = 0.00321928
# Iteration 157, loss = 0.00318777
# Iteration 158, loss = 0.00315905
# Iteration 159, loss = 0.00312611
# Iteration 160, loss = 0.00309227
# Iteration 161, loss = 0.00307172
# Iteration 162, loss = 0.00303582
# Iteration 163, loss = 0.00300431
# Iteration 164, loss = 0.00297579
# Iteration 165, loss = 0.00294792
# Iteration 166, loss = 0.00292016
# Iteration 167, loss = 0.00289233
# Iteration 168, loss = 0.00286457
# Iteration 169, loss = 0.00283667
# Iteration 170, loss = 0.00280893
# Iteration 171, loss = 0.00278618
# Iteration 172, loss = 0.00276345
# Iteration 173, loss = 0.00273123
# Iteration 174, loss = 0.00270973
# Iteration 175, loss = 0.00268620
# Iteration 176, loss = 0.00265863
# Iteration 177, loss = 0.00263874
# Iteration 178, loss = 0.00261246
# Iteration 179, loss = 0.00258955
# Iteration 180, loss = 0.00257075
# Iteration 181, loss = 0.00254813
# Iteration 182, loss = 0.00252624
# Iteration 183, loss = 0.00250594
# Iteration 184, loss = 0.00248312
# Iteration 185, loss = 0.00246024
# Iteration 186, loss = 0.00243926
# Iteration 187, loss = 0.00242116
# Iteration 188, loss = 0.00240065
# Iteration 189, loss = 0.00238089
# Iteration 190, loss = 0.00236531
# Iteration 191, loss = 0.00234266
# Iteration 192, loss = 0.00232680
# Iteration 193, loss = 0.00230797
# Iteration 194, loss = 0.00228874
# Iteration 195, loss = 0.00227364
# Iteration 196, loss = 0.00225214
# Iteration 197, loss = 0.00223483
# Iteration 198, loss = 0.00221812
# Iteration 199, loss = 0.00220289
# Iteration 200, loss = 0.00218535
# Iteration 201, loss = 0.00216759
# Iteration 202, loss = 0.00215225
# Iteration 203, loss = 0.00213717
# Iteration 204, loss = 0.00212090
# Iteration 205, loss = 0.00210378
# Iteration 206, loss = 0.00209065
# Iteration 207, loss = 0.00207344
# Iteration 208, loss = 0.00205893
# Iteration 209, loss = 0.00204393
# Iteration 210, loss = 0.00202943
# Iteration 211, loss = 0.00201671
# Iteration 212, loss = 0.00200101
# Iteration 213, loss = 0.00198844
# Iteration 214, loss = 0.00197337
# Iteration 215, loss = 0.00196026
# Iteration 216, loss = 0.00194613
# Iteration 217, loss = 0.00193408
# Iteration 218, loss = 0.00191876
# Iteration 219, loss = 0.00190651
# Iteration 220, loss = 0.00189456
# Iteration 221, loss = 0.00188010
# Iteration 222, loss = 0.00186866
# Iteration 223, loss = 0.00185643
# Iteration 224, loss = 0.00184353
# Iteration 225, loss = 0.00183149
# Iteration 226, loss = 0.00181925
# Iteration 227, loss = 0.00180783
# Iteration 228, loss = 0.00179671
# Iteration 229, loss = 0.00178447
# Iteration 230, loss = 0.00177403
# Iteration 231, loss = 0.00176234
# Iteration 232, loss = 0.00175142
# Iteration 233, loss = 0.00173973
# Iteration 234, loss = 0.00173078
# Iteration 235, loss = 0.00171822
# Iteration 236, loss = 0.00170796
# Iteration 237, loss = 0.00169826
# Iteration 238, loss = 0.00168642
# Iteration 239, loss = 0.00167598
# Iteration 240, loss = 0.00166778
# Iteration 241, loss = 0.00165616
# Iteration 242, loss = 0.00164841
# Iteration 243, loss = 0.00163628
# Iteration 244, loss = 0.00162624
# Iteration 245, loss = 0.00161741
# Iteration 246, loss = 0.00160787
# Iteration 247, loss = 0.00159838
# Iteration 248, loss = 0.00158991
# Iteration 249, loss = 0.00157951
# Iteration 250, loss = 0.00157004
# Iteration 251, loss = 0.00156146
# Iteration 252, loss = 0.00155294
# Iteration 253, loss = 0.00154423
# Iteration 254, loss = 0.00153434
# Iteration 255, loss = 0.00152615
# Iteration 256, loss = 0.00151900
# Iteration 257, loss = 0.00150921
# Iteration 258, loss = 0.00150033
# Iteration 259, loss = 0.00149243
# Iteration 260, loss = 0.00148468
# Training loss did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(90, 90), learning_rate='constant',
#        learning_rate_init=0.01, max_iter=500, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=1, shuffle=True, solver='sgd', tol=1e-05,
#        validation_fraction=0.1, verbose=10, warm_start=False)

# %%
# train_valid_combined = np.concatenate((train_data, validation_data))
# train_valid_label = np.concatenate((train_label, validation_label))

# %%
# clf =MLPClassifier(hidden_layer_sizes=(300,100, ), max_iter=200, alpha=1e-4,
#                     solver='adam', verbose=10, tol=1e-5, random_state=1,
#                     learning_rate_init=.1)
### acc is 98.41
clf2 = MLPClassifier(hidden_layer_sizes=(90, 90, ), max_iter=500, alpha=1e-4,
                    solver='sgd', verbose=10, tol=1e-5, random_state=1,
                    learning_rate_init=.01)
# Test set score: 0.950119

clf2.fit(train_valid_combined, train_valid_label)
# clf2.fit(train_data, train_label)
# Out:
# Iteration 1, loss = 1.02224680
# Iteration 2, loss = 0.92675198
# Iteration 3, loss = 0.80999612
# Iteration 4, loss = 0.67823693
# Iteration 5, loss = 0.53593339
# Iteration 6, loss = 0.41314037
# Iteration 7, loss = 0.32218058
# Iteration 8, loss = 0.26112435
# Iteration 9, loss = 0.21946152
# Iteration 10, loss = 0.19117238
# Iteration 11, loss = 0.16893869
# Iteration 12, loss = 0.15276147
# Iteration 13, loss = 0.13931217
# Iteration 14, loss = 0.12879925
# Iteration 15, loss = 0.11865822
# Iteration 16, loss = 0.11039377
# Iteration 17, loss = 0.10328784
# Iteration 18, loss = 0.09695791
# Iteration 19, loss = 0.09125820
# Iteration 20, loss = 0.08695790
# Iteration 21, loss = 0.08176838
# Iteration 22, loss = 0.07749568
# Iteration 23, loss = 0.07357044
# Iteration 24, loss = 0.07062555
# Iteration 25, loss = 0.06745713
# Iteration 26, loss = 0.06349538
# Iteration 27, loss = 0.06079741
# Iteration 28, loss = 0.05813080
# Iteration 29, loss = 0.05555543
# Iteration 30, loss = 0.05321685
# Iteration 31, loss = 0.05100043
# Iteration 32, loss = 0.04824410
# Iteration 33, loss = 0.04649834
# Iteration 34, loss = 0.04475271
# Iteration 35, loss = 0.04284307
# Iteration 36, loss = 0.04117239
# Iteration 37, loss = 0.03916011
# Iteration 38, loss = 0.03756572
# Iteration 39, loss = 0.03595863
# Iteration 40, loss = 0.03443733
# Iteration 41, loss = 0.03285807
# Iteration 42, loss = 0.03149271
# Iteration 43, loss = 0.03033601
# Iteration 44, loss = 0.02909756
# Iteration 45, loss = 0.02799537
# Iteration 46, loss = 0.02718358
# Iteration 47, loss = 0.02583286
# Iteration 48, loss = 0.02502657
# Iteration 49, loss = 0.02430125
# Iteration 50, loss = 0.02327732
# Iteration 51, loss = 0.02217255
# Iteration 52, loss = 0.02115364
# Iteration 53, loss = 0.02036357
# Iteration 54, loss = 0.01963276
# Iteration 55, loss = 0.01903901
# Iteration 56, loss = 0.01835308
# Iteration 57, loss = 0.01788107
# Iteration 58, loss = 0.01709397
# Iteration 59, loss = 0.01643907
# Iteration 60, loss = 0.01586634
# Iteration 61, loss = 0.01535300
# Iteration 62, loss = 0.01487549
# Iteration 63, loss = 0.01450267
# Iteration 64, loss = 0.01398218
# Iteration 65, loss = 0.01353907
# Iteration 66, loss = 0.01311848
# Iteration 67, loss = 0.01269098
# Iteration 68, loss = 0.01231769
# Iteration 69, loss = 0.01209210
# Iteration 70, loss = 0.01161698
# Iteration 71, loss = 0.01139224
# Iteration 72, loss = 0.01107473
# Iteration 73, loss = 0.01076730
# Iteration 74, loss = 0.01036551
# Iteration 75, loss = 0.01015514
# Iteration 76, loss = 0.00984503
# Iteration 77, loss = 0.00961596
# Iteration 78, loss = 0.00935478
# Iteration 79, loss = 0.00916825
# Iteration 80, loss = 0.00895169
# Iteration 81, loss = 0.00873726
# Iteration 82, loss = 0.00849953
# Iteration 83, loss = 0.00827722
# Iteration 84, loss = 0.00811942
# Iteration 85, loss = 0.00792530
# Iteration 86, loss = 0.00780786
# Iteration 87, loss = 0.00766209
# Iteration 88, loss = 0.00740008
# Iteration 89, loss = 0.00723984
# Iteration 90, loss = 0.00711615
# Iteration 91, loss = 0.00694946
# Iteration 92, loss = 0.00682003
# Iteration 93, loss = 0.00667414
# Iteration 94, loss = 0.00653923
# Iteration 95, loss = 0.00642006
# Iteration 96, loss = 0.00628313
# Iteration 97, loss = 0.00617481
# Iteration 98, loss = 0.00605409
# Iteration 99, loss = 0.00594154
# Iteration 100, loss = 0.00585785
# Iteration 101, loss = 0.00570893
# Iteration 102, loss = 0.00563750
# Iteration 103, loss = 0.00551760
# Iteration 104, loss = 0.00543303
# Iteration 105, loss = 0.00534098
# Iteration 106, loss = 0.00524099
# Iteration 107, loss = 0.00515343
# Iteration 108, loss = 0.00505571
# Iteration 109, loss = 0.00498215
# Iteration 110, loss = 0.00491010
# Iteration 111, loss = 0.00482252
# Iteration 112, loss = 0.00475548
# Iteration 113, loss = 0.00467881
# Iteration 114, loss = 0.00460352
# Iteration 115, loss = 0.00452203
# Iteration 116, loss = 0.00445625
# Iteration 117, loss = 0.00440728
# Iteration 118, loss = 0.00432711
# Iteration 119, loss = 0.00425579
# Iteration 120, loss = 0.00420145
# Iteration 121, loss = 0.00412645
# Iteration 122, loss = 0.00407834
# Iteration 123, loss = 0.00400593
# Iteration 124, loss = 0.00396902
# Iteration 125, loss = 0.00390304
# Iteration 126, loss = 0.00385908
# Iteration 127, loss = 0.00379037
# Iteration 128, loss = 0.00375032
# Iteration 129, loss = 0.00369372
# Iteration 130, loss = 0.00364641
# Iteration 131, loss = 0.00361517
# Iteration 132, loss = 0.00357066
# Iteration 133, loss = 0.00352942
# Iteration 134, loss = 0.00346879
# Iteration 135, loss = 0.00341105
# Iteration 136, loss = 0.00336940
# Iteration 137, loss = 0.00333454
# Iteration 138, loss = 0.00329107
# Iteration 139, loss = 0.00325330
# Iteration 140, loss = 0.00320577
# Iteration 141, loss = 0.00317515
# Iteration 142, loss = 0.00313818
# Iteration 143, loss = 0.00309576
# Iteration 144, loss = 0.00306003
# Iteration 145, loss = 0.00302370
# Iteration 146, loss = 0.00299178
# Iteration 147, loss = 0.00295164
# Iteration 148, loss = 0.00293325
# Iteration 149, loss = 0.00289465
# Iteration 150, loss = 0.00286223
# Iteration 151, loss = 0.00282619
# Iteration 152, loss = 0.00279254
# Iteration 153, loss = 0.00276664
# Iteration 154, loss = 0.00273396
# Iteration 155, loss = 0.00270316
# Iteration 156, loss = 0.00268191
# Iteration 157, loss = 0.00265275
# Iteration 158, loss = 0.00262360
# Iteration 159, loss = 0.00259260
# Iteration 160, loss = 0.00256590
# Iteration 161, loss = 0.00254238
# Iteration 162, loss = 0.00251290
# Iteration 163, loss = 0.00249280
# Iteration 164, loss = 0.00246670
# Iteration 165, loss = 0.00243997
# Iteration 166, loss = 0.00242494
# Iteration 167, loss = 0.00239258
# Iteration 168, loss = 0.00237287
# Iteration 169, loss = 0.00235076
# Iteration 170, loss = 0.00232081
# Iteration 171, loss = 0.00230325
# Iteration 172, loss = 0.00228284
# Iteration 173, loss = 0.00226026
# Iteration 174, loss = 0.00223712
# Iteration 175, loss = 0.00221983
# Iteration 176, loss = 0.00219728
# Iteration 177, loss = 0.00217975
# Iteration 178, loss = 0.00215875
# Iteration 179, loss = 0.00214659
# Iteration 180, loss = 0.00211801
# Iteration 181, loss = 0.00210248
# Iteration 182, loss = 0.00209129
# Iteration 183, loss = 0.00206635
# Iteration 184, loss = 0.00204703
# Iteration 185, loss = 0.00203030
# Iteration 186, loss = 0.00201391
# Iteration 187, loss = 0.00199462
# Iteration 188, loss = 0.00198047
# Iteration 189, loss = 0.00196056
# Iteration 190, loss = 0.00194711
# Iteration 191, loss = 0.00193229
# Iteration 192, loss = 0.00191370
# Iteration 193, loss = 0.00189773
# Iteration 194, loss = 0.00188420
# Iteration 195, loss = 0.00186666
# Iteration 196, loss = 0.00185367
# Iteration 197, loss = 0.00183833
# Iteration 198, loss = 0.00182902
# Iteration 199, loss = 0.00180790
# Iteration 200, loss = 0.00179804
# Iteration 201, loss = 0.00178148
# Iteration 202, loss = 0.00176936
# Iteration 203, loss = 0.00175561
# Iteration 204, loss = 0.00174369
# Iteration 205, loss = 0.00172669
# Iteration 206, loss = 0.00171374
# Iteration 207, loss = 0.00170202
# Iteration 208, loss = 0.00168883
# Iteration 209, loss = 0.00167659
# Iteration 210, loss = 0.00166559
# Iteration 211, loss = 0.00165203
# Iteration 212, loss = 0.00163915
# Iteration 213, loss = 0.00162936
# Iteration 214, loss = 0.00161659
# Iteration 215, loss = 0.00160553
# Iteration 216, loss = 0.00159376
# Iteration 217, loss = 0.00158315
# Iteration 218, loss = 0.00157180
# Iteration 219, loss = 0.00155996
# Iteration 220, loss = 0.00155023
# Iteration 221, loss = 0.00154039
# Iteration 222, loss = 0.00153057
# Iteration 223, loss = 0.00151967
# Iteration 224, loss = 0.00150910
# Iteration 225, loss = 0.00149982
# Iteration 226, loss = 0.00148976
# Iteration 227, loss = 0.00147908
# Iteration 228, loss = 0.00146863
# Iteration 229, loss = 0.00145830
# Iteration 230, loss = 0.00144963
# Iteration 231, loss = 0.00144201
# Iteration 232, loss = 0.00142995
# Iteration 233, loss = 0.00142309
# Iteration 234, loss = 0.00141168
# Iteration 235, loss = 0.00140302
# Iteration 236, loss = 0.00139441
# Iteration 237, loss = 0.00138508
# Iteration 238, loss = 0.00137738
# Iteration 239, loss = 0.00136752
# Iteration 240, loss = 0.00135981
# Iteration 241, loss = 0.00135156
# Iteration 242, loss = 0.00134243
# Iteration 243, loss = 0.00133409
# Iteration 244, loss = 0.00132714
# Iteration 245, loss = 0.00131895
# Training loss did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(90, 90), learning_rate='constant',
#        learning_rate_init=0.01, max_iter=500, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=1, shuffle=True, solver='sgd', tol=1e-05,
#        validation_fraction=0.1, verbose=10, warm_start=False)

# %%
train_valid_combined.shape
# Out:
# (2000, 180)

# %%
clf.score(train_data,train_label)
# Out:
# 1.0

# %%
clf.score(validation_data,validation_label)
# Out:
# 0.9366666666666666

# %%
clf.score(test_data,test_label)
# Out:
# 0.9333895446880269

# %%
clf2.score(train_data,train_label)
# Out:
# 1.0

# %%
clf2.score(validation_data,validation_label)
# Out:
# 1.0

# %%
clf.score(test_data,test_label)
# Out:
# 0.9333895446880269

# %%
clf2.score(test_data,test_label)
# Out:
# 0.948566610455312

# %%
enc = OneHotEncoder(handle_unknown='ignore',sparse=False)
enc.fit(train_label.reshape(1,-1).T)
train_label_one_hot = enc.transform(train_label.reshape(-1,1))
test_label_one_hot = enc.transform(test_label.reshape(-1,1))
validation_label_one_hot = enc.transform(validation_label.reshape(-1,1))
validation_test_label_one_hot = enc.transform(train_valid_label.reshape(-1,1))

# %%
test_label_one_hot.shape
# Out:
# (1186, 3)

# %%
def next_batch(num, data, labels):
    '''
    Return a total of `num` random samples and labels. 
    '''
    idx = np.arange(0 , len(data))
    np.random.shuffle(idx)
    idx = idx[:num]
    data_shuffle = [data[ i] for i in idx]
    labels_shuffle = [labels[ i] for i in idx]
    
    return np.asarray(data_shuffle), np.asarray(labels_shuffle)

# %%
def xavier_init(size):
    in_dim = size[0]
    xavier_stddev = 1. / tf.sqrt(in_dim / 2.)
    return tf.random_normal(shape=size, stddev=xavier_stddev, seed=1000)

# %%
## Define weights of the layer



# saver = tf.train.Saver()

# %% [markdown]
# #### Divide valid in two parts for validation and validation-test

# %%
plt.hist(np.argmax(train_label_one_hot,axis = 1))
# Out:
# (array([331.,   0.,   0.,   0.,   0., 329.,   0.,   0.,   0., 740.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(np.argmax(validation_label_one_hot,axis = 1))
# Out:
# (array([133.,   0.,   0.,   0.,   0., 156.,   0.,   0.,   0., 311.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <a list of 10 Patch objects>)

# %%
from sklearn.utils import shuffle  #train_data, train_label

X_train, y_train = shuffle(train_data, train_label_one_hot)
validation_data, validation_label_one_hot = validation_data, validation_label_one_hot

# %% [markdown]
# ## Setup TensorFlow
# The `EPOCH` and `BATCH_SIZE` values affect the training speed and model accuracy.
#
# You do not need to modify this section.

# %%
import tensorflow as tf

EPOCHS = 100
BATCH_SIZE = 512

# %%
connection_probability = tf.Variable(.9999)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
print(X_train.shape)
# print(G_W1.shape)
# print(G_W2.shape)
# print(G_W3.shape)
# Out:
# (1400, 180)

# %% [markdown]
# #### Define the network

# %%
G_W1 = tf.Variable(np.float32(clf.coefs_[0]))
G_b1 = tf.Variable(np.float32(clf.intercepts_ [0]))

G_W2 =  tf.Variable(np.float32(clf.coefs_[1]))
G_b2 = tf.Variable(np.float32(clf.intercepts_ [1]))

G_W3 =  tf.Variable(np.float32(clf.coefs_[2]))
G_b3 = tf.Variable(np.float32(clf.intercepts_ [2]))

# G_w_out_h1 = tf.Variable(xavier_init([10,80]))
# G_b_out_h1 = tf.Variable(xavier_init([80]))

# G_w_h2_h1 = tf.Variable(xavier_init([40,80]))
# G_b_h2_h1 = tf.Variable(xavier_init([80]))


# G_w_h1_input = tf.Variable(xavier_init([80,16]))
# G_b_h1_input = tf.Variable(xavier_init([16]))


# G_w_input_h1_h2 = tf.Variable(xavier_init([16,40]))
# G_b_h1_input = tf.Variable(xavier_init([40]))

# %%
from tensorflow.contrib.layers import flatten

def LeNet(x, test_mode = False):    
    # Hyperparameters
    mu = 0
    sigma = 0.1
    layer_depth = {
        'layer_1' : 6,
        'layer_2' : 16,
        'layer_3' : 120,
        'layer_f1' : 84
    }


    
    # TODO: Flatten. Input = 5x5x16. Output = 400.
    x_flat = flatten(x)
    fc1 = flatten(x)
    fdense = fc1
    
    # TODO: Layer 3: Fully Connected. Input = 400. Output = 120.
    fc1_w = G_W1# tf.Variable(tf.truncated_normal(shape = (X_train.shape[1]*X_train.shape[2],300), mean = mu, stddev = sigma))
    fc1_b = G_b1# tf.Variable(tf.zeros(300))
    fc1 = tf.matmul(fc1,fc1_w) + fc1_b
    
    # TODO: Activation.
    fc1 = tf.nn.relu(fc1)

    # TODO: Layer 4: Fully Connected. Input = 120. Output = 84.
    fc2_w = G_W2# tf.Variable(tf.truncated_normal(shape = (300,100), mean = mu, stddev = sigma))
    fc2_b = G_b2# tf.Variable(tf.zeros(100))
    fc2 = tf.matmul(fc1,fc2_w) + fc2_b
    # TODO: Activation.
    fc2 = tf.nn.relu(fc2)
    
    
    #################
    ##### Inset probability connection from x to conv2
    fc2p_w = tf.Variable(xavier_init([X_train.shape[1],clf.coefs_[1].shape[1]]))
    fc2p_b = tf.Variable(xavier_init([clf.coefs_[1].shape[1]]))
    fc2_2nd_input = tf.matmul(x_flat,fc2p_w) + fc2p_b
    fc2_2nd_input = tf.nn.relu(fc2_2nd_input)
    connect2 = tf.logical_and(tf.random.uniform(shape = tf.shape(connection_probability)) < connection_probability, tf.equal(test_mode,False))
    fc2 = tf.cond(connect2,lambda: fc2 + fc2_2nd_input, lambda: fc2 )    
    ################    
    fc3_w = G_W3
    fc3_b = G_b3
    
    logits = tf.matmul(fc2, fc3_w) + fc3_b
#     print(logits.shape)
    return logits

# %%
train_label_one_hot.shape
# Out:
# (1400, 3)

# %%
train_label
# Out:
# array([1, 1, 1, ..., 2, 2, 0])

# %%
with tf.name_scope('Input'):

  x = tf.placeholder(tf.float32, (None, train_data.shape[1]), name='X')
  y = tf.placeholder("float", [None, 1+np.max(train_label)])
# one_hot_y = tf.one_hot(y, train_label_one_hot.shape[1])
is_testing= tf.placeholder(tf.bool)

# %%
BATCH_SIZE = 1024

# %%
rate = 0.001
decay_rate = 1.0005**(X_train.shape[0]/BATCH_SIZE);
decay_rate = 1.2
print(decay_rate)
logits = LeNet(x,is_testing)
with tf.name_scope('Train'):
#   cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits = logits, labels = one_hot_y)
#   loss_operation = tf.reduce_mean(cross_entropy, name='loss')
  loss_operation = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=LeNet(x, test_mode=False), labels=y))
  tf.summary.scalar('loss', loss_operation)
# optimizer = tf.train.MomentumOptimizer(learning_rate = rate,momentum=.9)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
# tf.train.natural_exp_decay()
training_operation = optimizer.minimize(loss_operation)
new_prob = connection_probability.assign(connection_probability/decay_rate)
# Out:
# 1.2
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/layers/python/layers/layers.py:1624: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From <ipython-input-31-76fbcb82bbf5>:9: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %%
# def evaluate(X_data, y_data):
correct_pred = tf.equal(tf.argmax(LeNet(x,test_mode=True), 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
# correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
# accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
# saver = tf.train.Saver()

# def evaluate(X_data, y_data):
#     num_examples = len(X_data)
#     total_accuracy = 0
#     sess = tf.get_default_session()
#     for offset in range(0, num_examples, BATCH_SIZE):
#         batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
#         accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y, is_testing: True})
#         total_accuracy += (accuracy * len(batch_x))
#     tot_acc = total_accuracy / num_examples
#     with tf.name_scope('Accuracy'):
#       tf.summary.scalar('accuracy', tot_acc)
#     return total_accuracy / num_examples

# %% [markdown]
# ### Train the mode

# %%
2056*2
# Out:
# 4112

# %%
BATCH_SIZE = 1024

# %%
EPOCHS = 5000

# %%
saver = tf.train.Saver()

# %%
X_train.shape
# Out:
# (1400, 180)

# %%
validation_accuracy_track = []
train_accuracy_track = []
connection_probability_track = []
number_of_ex = X_train.shape[0]
total_steps_for_one_pass = number_of_ex//BATCH_SIZE + 1
epoch_track = []
print_every = 10
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    best_accuracy_valid = 0
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for step in range(0, total_steps_for_one_pass):        
          if step>=number_of_ex//BATCH_SIZE:
            batch_x, batch_y = X_train[step*BATCH_SIZE:,:],y_train[step*BATCH_SIZE:]
#             print(step,'Finishing',step*BATCH_SIZE )
            step = 0

          else:

            start = step*BATCH_SIZE
            finish = (step+1)*BATCH_SIZE
#             print(step,'Doing', 'Start = ', start, "Finish = ", finish)
            batch_x, batch_y = X_train[step:finish,:],y_train[step:finish]
#           print(batch_y.shape)
          tr_op  = sess.run([training_operation], feed_dict={x: batch_x, y: batch_y, is_testing : False})
#           train_writer.add_summary(summary_tr, i)
        prob = sess.run(new_prob)
        if i%print_every == 0:
          tr_accuracy = sess.run(accuracy*100, feed_dict={x: X_train,y:y_train, is_testing: True})  # evaluate(X_train, y_train)
          print("Train Accuracy = {:.5f}".format(tr_accuracy))
          validation_accuracy = sess.run(accuracy*100, feed_dict={x: validation_data,y:validation_label_one_hot, is_testing: True}) #evaluate(X_validation, y_validation)
          validation_accuracy_track.append(validation_accuracy)
          train_accuracy_track.append(tr_accuracy)
          epoch_track.append(i)
          connection_probability_track.append(prob)
          print("EPOCH {} ...".format(i+1))
          print("Validation Accuracy = {:.5f}".format(validation_accuracy))
          print(prob)
          print()
          if (validation_accuracy >= best_accuracy_valid):
            best_accuracy_valid = validation_accuracy
            saver.save(sess, './DNAAdamBased')
        
#     saver.save(sess, './lenet')
    print("Model saved")
# Out:
# Training...
#
# Train Accuracy = 100.00000
# EPOCH 1 ...
# Validation Accuracy = 93.83334
# 0.83325
#
# Train Accuracy = 100.00000
# EPOCH 11 ...
# Validation Accuracy = 92.83334
# 0.1345745
#
# Train Accuracy = 100.00000
# EPOCH 21 ...
# Validation Accuracy = 93.33334
# 0.021734525
#
# Train Accuracy = 100.00000
# EPOCH 31 ...
# Validation Accuracy = 94.00000
# 0.0035102463
#
# Train Accuracy = 100.00000
# EPOCH 41 ...
# Validation Accuracy = 94.16666
# 0.0005669242
#
# Train Accuracy = 100.00000
# EPOCH 51 ...
# Validation Accuracy = 94.00000
# 9.156141e-05
#
# Train Accuracy = 100.00000
# EPOCH 61 ...
# Validation Accuracy = 94.00000
# 1.4787675e-05
#
# Train Accuracy = 100.00000
# EPOCH 71 ...
# Validation Accuracy = 94.00000
# 2.3882915e-06
#
# Train Accuracy = 100.00000
# EPOCH 81 ...
# Validation Accuracy = 94.16666
# 3.8572227e-07
#
# Train Accuracy = 100.00000
# EPOCH 91 ...
# Validation Accuracy = 94.16666
# 6.229629e-08
#
# Train Accuracy = 100.00000
# EPOCH 101 ...
# Validation Accuracy = 94.16666
# 1.0061196e-08
#
# Train Accuracy = 100.00000
# EPOCH 111 ...
# Validation Accuracy = 94.16666
# 1.6249389e-09
#
# Train Accuracy = 100.00000
# EPOCH 121 ...
# Validation Accuracy = 94.16666
# 2.6243663e-10
#
# Train Accuracy = 100.00000
# EPOCH 131 ...
# Validation Accuracy = 94.16666
# 4.238497e-11
#
# Train Accuracy = 100.00000
# EPOCH 141 ...
# Validation Accuracy = 94.16666
# 6.845409e-12
#
# Train Accuracy = 100.00000
# EPOCH 151 ...
# Validation Accuracy = 94.16666
# 1.1055714e-12
#
# Train Accuracy = 100.00000
# EPOCH 161 ...
# Validation Accuracy = 94.33334
# 1.7855591e-13
#
# Train Accuracy = 100.00000
# EPOCH 171 ...
# Validation Accuracy = 94.33334
# 2.8837775e-14
#
# Train Accuracy = 100.00000
# EPOCH 181 ...
# Validation Accuracy = 94.16666
# 4.6574606e-15
#
# Train Accuracy = 100.00000
# EPOCH 191 ...
# Validation Accuracy = 94.16666
# 7.522058e-16
#
# Train Accuracy = 100.00000
# EPOCH 201 ...
# Validation Accuracy = 94.16666
# 1.214854e-16
#
# Train Accuracy = 100.00000
# EPOCH 211 ...
# Validation Accuracy = 94.16666
# 1.9620562e-17
#
# Train Accuracy = 100.00000
# EPOCH 221 ...
# Validation Accuracy = 94.16666
# 3.1688293e-18
#
# Train Accuracy = 100.00000
# EPOCH 231 ...
# Validation Accuracy = 94.16666
# 5.117835e-19
#
# Train Accuracy = 100.00000
# EPOCH 241 ...
# Validation Accuracy = 94.16666
# 8.2655874e-20
#
# Train Accuracy = 100.00000
# EPOCH 251 ...
# Validation Accuracy = 94.16666
# 1.33493824e-20
#
# Train Accuracy = 100.00000
# EPOCH 261 ...
# Validation Accuracy = 94.16666
# 2.1559994e-21
#
# Train Accuracy = 100.00000
# EPOCH 271 ...
# Validation Accuracy = 94.16666
# 3.4820585e-22
#
# Train Accuracy = 100.00000
# EPOCH 281 ...
# Validation Accuracy = 94.16666
# 5.6237174e-23
#
# Train Accuracy = 100.00000
# EPOCH 291 ...
# Validation Accuracy = 94.16666
# 9.0826155e-24
#
# Train Accuracy = 100.00000
# EPOCH 301 ...
# Validation Accuracy = 94.00000
# 1.4668928e-24
#
# Train Accuracy = 100.00000
# EPOCH 311 ...
# Validation Accuracy = 94.00000
# 2.369113e-25
#
# Train Accuracy = 100.00000
# EPOCH 321 ...
# Validation Accuracy = 94.00000
# 3.8262487e-26
#
# Train Accuracy = 100.00000
# EPOCH 331 ...
# Validation Accuracy = 94.00000
# 6.1796043e-27
#
# Train Accuracy = 100.00000
# EPOCH 341 ...
# Validation Accuracy = 94.00000
# 9.980403e-28
#
# Train Accuracy = 100.00000
# EPOCH 351 ...
# Validation Accuracy = 94.00000
# 1.6118906e-28
#
# Train Accuracy = 100.00000
# EPOCH 361 ...
# Validation Accuracy = 94.00000
# 2.6032927e-29
#
# Train Accuracy = 100.00000
# EPOCH 371 ...
# Validation Accuracy = 94.00000
# 4.2044616e-30
#
# Train Accuracy = 100.00000
# EPOCH 381 ...
# Validation Accuracy = 94.00000
# 6.7904387e-31
#
# Train Accuracy = 100.00000
# EPOCH 391 ...
# Validation Accuracy = 94.00000
# 1.0966934e-31
#
# Train Accuracy = 100.00000
# EPOCH 401 ...
# Validation Accuracy = 94.00000
# 1.771221e-32
#
# Train Accuracy = 100.00000
# EPOCH 411 ...
# Validation Accuracy = 94.00000
# 2.8606202e-33
#
# Train Accuracy = 100.00000
# EPOCH 421 ...
# Validation Accuracy = 94.00000
# 4.6200606e-34
#
# Train Accuracy = 100.00000
# EPOCH 431 ...
# Validation Accuracy = 94.00000
# 7.461655e-35
#
# Train Accuracy = 100.00000
# EPOCH 441 ...
# Validation Accuracy = 94.00000
# 1.2050985e-35
#
# Train Accuracy = 100.00000
# EPOCH 451 ...
# Validation Accuracy = 94.00000
# 1.946301e-36
#
# Train Accuracy = 100.00000
# EPOCH 461 ...
# Validation Accuracy = 94.00000
# 3.1433837e-37
#
# Train Accuracy = 100.00000
# EPOCH 471 ...
# Validation Accuracy = 94.00000
# 5.076739e-38
#
# Train Accuracy = 100.00000
# EPOCH 481 ...
# Validation Accuracy = 94.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 491 ...
# Validation Accuracy = 94.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 501 ...
# Validation Accuracy = 94.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 511 ...
# Validation Accuracy = 94.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 521 ...
# Validation Accuracy = 94.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 531 ...
# Validation Accuracy = 94.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 541 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 551 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 561 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 571 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 581 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 591 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 601 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 611 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 621 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 631 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 641 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 651 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 661 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 671 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 681 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 691 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 701 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 711 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 721 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 731 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 741 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 751 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 761 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 771 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 781 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 791 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 801 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 811 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 821 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 831 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 841 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 851 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 861 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 871 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 881 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 891 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 901 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 911 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 921 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 931 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 941 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 951 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 961 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 971 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 981 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 991 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1001 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1011 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1021 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1031 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1041 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1051 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1061 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1071 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1081 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1091 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1101 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1111 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1121 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1131 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1141 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1151 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1161 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1171 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1181 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1191 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1201 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1211 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1221 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1231 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1241 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1251 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1261 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1271 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1281 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1291 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1301 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1311 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1321 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1331 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1341 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1351 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1361 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1371 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1381 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1391 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1401 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1411 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1421 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1431 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1441 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1451 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1461 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1471 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1481 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1491 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1501 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1511 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1521 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1531 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1541 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1551 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1561 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1571 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1581 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1591 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1601 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1611 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1621 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1631 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1641 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1651 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1661 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1671 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1681 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1691 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1701 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1711 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1721 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1731 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1741 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1751 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1761 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1771 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1781 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1791 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1801 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1811 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1821 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1831 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1841 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1851 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1861 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1871 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1881 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1891 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1901 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1911 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1921 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1931 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1941 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1951 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1961 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1971 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1981 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1991 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2001 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2011 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2021 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2031 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2041 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2051 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2061 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2071 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2081 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2091 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2101 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2111 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2121 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2131 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2141 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2151 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2161 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2171 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2181 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2191 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2201 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2211 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2221 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2231 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2241 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2251 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2261 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2271 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2281 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2291 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2301 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2311 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2321 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2331 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2341 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2351 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2361 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2371 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2381 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2391 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2401 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2411 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2421 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2431 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2441 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2451 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2461 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2471 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2481 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2491 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2501 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2511 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2521 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2531 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2541 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2551 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2561 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2571 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2581 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2591 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2601 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2611 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2621 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2631 ...
# Validation Accuracy = 94.16666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2641 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2651 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2661 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2671 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2681 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2691 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2701 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2711 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2721 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2731 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2741 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2751 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2761 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2771 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2781 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2791 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2801 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2811 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2821 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2831 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2841 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2851 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2861 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2871 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2881 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2891 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2901 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2911 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2921 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2931 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2941 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2951 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2961 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2971 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2981 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2991 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3001 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3011 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3021 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3031 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3041 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3051 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3061 ...
# Validation Accuracy = 94.33334
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3071 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3081 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3091 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3101 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3111 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3121 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3131 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3141 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3151 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3161 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3171 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3181 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3191 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3201 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3211 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3221 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3231 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3241 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3251 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3261 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3271 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3281 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3291 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3301 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3311 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3321 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3331 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3341 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3351 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3361 ...
# Validation Accuracy = 94.66666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3371 ...
# Validation Accuracy = 94.66666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3381 ...
# Validation Accuracy = 94.66666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3391 ...
# Validation Accuracy = 94.66666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3401 ...
# Validation Accuracy = 94.66666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3411 ...
# Validation Accuracy = 94.66666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3421 ...
# Validation Accuracy = 94.66666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3431 ...
# Validation Accuracy = 94.66666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3441 ...
# Validation Accuracy = 94.66666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3451 ...
# Validation Accuracy = 94.66666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3461 ...
# Validation Accuracy = 94.66666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3471 ...
# Validation Accuracy = 94.66666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3481 ...
# Validation Accuracy = 94.66666
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3491 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3501 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3511 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3521 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3531 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3541 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3551 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3561 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3571 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3581 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3591 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3601 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3611 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3621 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3631 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3641 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3651 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3661 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3671 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3681 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3691 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3701 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3711 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3721 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3731 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3741 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3751 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3761 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3771 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3781 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3791 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3801 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3811 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3821 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3831 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3841 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3851 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3861 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3871 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3881 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3891 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3901 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3911 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3921 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3931 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3941 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3951 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3961 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3971 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3981 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3991 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4001 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4011 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4021 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4031 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4041 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4051 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4061 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4071 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4081 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4091 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4101 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4111 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4121 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4131 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4141 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4151 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4161 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4171 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4181 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4191 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4201 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4211 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4221 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4231 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4241 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4251 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4261 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4271 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4281 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4291 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4301 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4311 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4321 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4331 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4341 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4351 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4361 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4371 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4381 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4391 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4401 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4411 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4421 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4431 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4441 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4451 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4461 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4471 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4481 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4491 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4501 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4511 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4521 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4531 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4541 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4551 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4561 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4571 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4581 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4591 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4601 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4611 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4621 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4631 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4641 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4651 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4661 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4671 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4681 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4691 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4701 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4711 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4721 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4731 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4741 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4751 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4761 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4771 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4781 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4791 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4801 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4811 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4821 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4831 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4841 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4851 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4861 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4871 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4881 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4891 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4901 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4911 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4921 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4931 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4941 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4951 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4961 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4971 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4981 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 4991 ...
# Validation Accuracy = 94.50000
# 0.0
#
# Model saved

# %%
np.argmax(validation_accuracy_track)
# Out:
# 336

# %%
best_accuracy_valid
# Out:
# 94.666664

# %%
with tf.Session() as sess:
#     saver.restore(sess, tf.train.latest_checkpoint('.'))
    saver.restore(sess, './DNAAdamBased')
    validation_accuracy = sess.run(accuracy*100, feed_dict={x: validation_data,y:validation_label_one_hot, is_testing: True})
    print("Validation Accuracy = {:.6f}".format(validation_accuracy))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./DNAAdamBased
# Validation Accuracy = 94.666664

# %%
import matplotlib.pyplot as plt
from scipy.interpolate import spline
from scipy.signal import savgol_filter

# %%
steps_plot =  [step for step in range(0, 4861, print_every)]

# %%
len(validation_accuracy_track)
# Out:
# 500

# %%
# plt.plot( savgol_filter(np.asarray(validation_accuracy_track),51,1))
plt.plot( (validation_accuracy_track))

# %%
# len(steps_plot)

# %%
steps_plot = epoch_track# [step for step in range(0, 2291, print_every)]
# plt.plot(steps_plot, 100*np.asarray(train_accuracy))
# plt.plot(steps_plot, val_accuracy)

plt.plot(steps_plot, np.asarray(train_accuracy_track))  
plt.plot(steps_plot, validation_accuracy_track)
plt.tight_layout()
# plt.xticks(np.arange(min(steps_plot), max(steps_plot)+1, 2000))
plt.ylabel('Accuracy')
plt.grid(abs)
plt.show()

# %%
valid_accuracy_filtered = validation_accuracy_track
print(max(valid_accuracy_filtered))
valid_accuracy_filtered_np = np.asarray(valid_accuracy_filtered)
print(np.argmax(valid_accuracy_filtered))
print(steps_plot[np.argmax(valid_accuracy_filtered)])
# Out:
# 94.666664
# 336
# 3360

# %%
import scipy.io as sio

# %%
sio.savemat('DNAFullDatasetMomentADAM_ProbabilityBasedValid94p67.mat', {'ValidationTracked':validation_accuracy_track,
                                       'train_accuracy_track':train_accuracy_track,
                                       'connection_probability_track':connection_probability_track,
                                       'epochTrack':epoch_track, 'TestAcc':'test_accuracy',
                                                         'BestValidation':best_accuracy_valid})

# %% [markdown]
# ### Now  retrain til 3151 Epochs

# %%
# keep aside 
aside_examples= 1
aside_valid_test = train_valid_combined[-aside_examples:]
aside_valid_test_label = validation_test_label_one_hot[-aside_examples:]
combined_train_valid = train_valid_combined[:train_valid_combined.shape[0]-aside_examples,:]
combined_train_valid_label = validation_test_label_one_hot[:train_valid_combined.shape[0]-aside_examples,:]

# %%
EPOCHS = 3361

# %%
validation_accuracy_track = []
train_accuracy_track = []
connection_probability_track = []
number_of_ex = combined_train_valid.shape[0]
total_steps_for_one_pass = number_of_ex//BATCH_SIZE + 1

print_every = 10
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    best_accuracy_valid = 0
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(combined_train_valid, combined_train_valid_label)
        for step in range(0, total_steps_for_one_pass):        
          if step>=number_of_ex//BATCH_SIZE:
            batch_x, batch_y = X_train[step*BATCH_SIZE:,:],y_train[step*BATCH_SIZE:]
#             print(step,'Finishing',step*BATCH_SIZE )
            step = 0

          else:

            start = step*BATCH_SIZE
            finish = (step+1)*BATCH_SIZE
#             print(step,'Doing', 'Start = ', start, "Finish = ", finish)
            batch_x, batch_y = X_train[step:finish,:],y_train[step:finish]
#           print(batch_y.shape)
          tr_op  = sess.run([training_operation], feed_dict={x: batch_x, y: batch_y, is_testing : False})
#           train_writer.add_summary(summary_tr, i)
        prob = sess.run(new_prob)
        if i%print_every == 0:
          tr_accuracy = sess.run(accuracy*100, feed_dict={x: X_train,y:y_train, is_testing: True})  # evaluate(X_train, y_train)
          print("Train Accuracy = {:.5f}".format(tr_accuracy))
          validation_accuracy = sess.run(accuracy*100, feed_dict={x: aside_valid_test,y:aside_valid_test_label, is_testing: True}) #evaluate(X_validation, y_validation)
          validation_accuracy_track.append(validation_accuracy)
          train_accuracy_track.append(tr_accuracy)
          connection_probability_track.append(prob)
          print("EPOCH {} ...".format(i+1))
          print("Validation Accuracy = {:.5f}".format(validation_accuracy))
          print(prob)
          print()
          if (validation_accuracy >= best_accuracy_valid):
            best_accuracy_valid = validation_accuracy
#             saver.save(sess, './PendigitSGDBased')
    saver.save(sess, './DNAAdamBasedAllPass')   
#     saver.save(sess, './lenet')
    print("Model saved")
# Out:
# Training...
#
# Train Accuracy = 98.14907
# EPOCH 1 ...
# Validation Accuracy = 100.00000
# 0.83325
#
# Train Accuracy = 99.74988
# EPOCH 11 ...
# Validation Accuracy = 100.00000
# 0.1345745
#
# Train Accuracy = 99.94997
# EPOCH 21 ...
# Validation Accuracy = 100.00000
# 0.021734525
#
# Train Accuracy = 100.00000
# EPOCH 31 ...
# Validation Accuracy = 100.00000
# 0.0035102463
#
# Train Accuracy = 100.00000
# EPOCH 41 ...
# Validation Accuracy = 100.00000
# 0.0005669242
#
# Train Accuracy = 100.00000
# EPOCH 51 ...
# Validation Accuracy = 100.00000
# 9.156141e-05
#
# Train Accuracy = 100.00000
# EPOCH 61 ...
# Validation Accuracy = 100.00000
# 1.4787675e-05
#
# Train Accuracy = 100.00000
# EPOCH 71 ...
# Validation Accuracy = 100.00000
# 2.3882915e-06
#
# Train Accuracy = 100.00000
# EPOCH 81 ...
# Validation Accuracy = 100.00000
# 3.8572227e-07
#
# Train Accuracy = 100.00000
# EPOCH 91 ...
# Validation Accuracy = 100.00000
# 6.229629e-08
#
# Train Accuracy = 100.00000
# EPOCH 101 ...
# Validation Accuracy = 100.00000
# 1.0061196e-08
#
# Train Accuracy = 100.00000
# EPOCH 111 ...
# Validation Accuracy = 100.00000
# 1.6249389e-09
#
# Train Accuracy = 100.00000
# EPOCH 121 ...
# Validation Accuracy = 100.00000
# 2.6243663e-10
#
# Train Accuracy = 100.00000
# EPOCH 131 ...
# Validation Accuracy = 100.00000
# 4.238497e-11
#
# Train Accuracy = 100.00000
# EPOCH 141 ...
# Validation Accuracy = 100.00000
# 6.845409e-12
#
# Train Accuracy = 100.00000
# EPOCH 151 ...
# Validation Accuracy = 100.00000
# 1.1055714e-12
#
# Train Accuracy = 100.00000
# EPOCH 161 ...
# Validation Accuracy = 100.00000
# 1.7855591e-13
#
# Train Accuracy = 100.00000
# EPOCH 171 ...
# Validation Accuracy = 100.00000
# 2.8837775e-14
#
# Train Accuracy = 100.00000
# EPOCH 181 ...
# Validation Accuracy = 100.00000
# 4.6574606e-15
#
# Train Accuracy = 100.00000
# EPOCH 191 ...
# Validation Accuracy = 100.00000
# 7.522058e-16
#
# Train Accuracy = 100.00000
# EPOCH 201 ...
# Validation Accuracy = 100.00000
# 1.214854e-16
#
# Train Accuracy = 100.00000
# EPOCH 211 ...
# Validation Accuracy = 100.00000
# 1.9620562e-17
#
# Train Accuracy = 100.00000
# EPOCH 221 ...
# Validation Accuracy = 100.00000
# 3.1688293e-18
#
# Train Accuracy = 100.00000
# EPOCH 231 ...
# Validation Accuracy = 100.00000
# 5.117835e-19
#
# Train Accuracy = 100.00000
# EPOCH 241 ...
# Validation Accuracy = 100.00000
# 8.2655874e-20
#
# Train Accuracy = 100.00000
# EPOCH 251 ...
# Validation Accuracy = 100.00000
# 1.33493824e-20
#
# Train Accuracy = 100.00000
# EPOCH 261 ...
# Validation Accuracy = 100.00000
# 2.1559994e-21
#
# Train Accuracy = 100.00000
# EPOCH 271 ...
# Validation Accuracy = 100.00000
# 3.4820585e-22
#
# Train Accuracy = 100.00000
# EPOCH 281 ...
# Validation Accuracy = 100.00000
# 5.6237174e-23
#
# Train Accuracy = 100.00000
# EPOCH 291 ...
# Validation Accuracy = 100.00000
# 9.0826155e-24
#
# Train Accuracy = 100.00000
# EPOCH 301 ...
# Validation Accuracy = 100.00000
# 1.4668928e-24
#
# Train Accuracy = 100.00000
# EPOCH 311 ...
# Validation Accuracy = 100.00000
# 2.369113e-25
#
# Train Accuracy = 100.00000
# EPOCH 321 ...
# Validation Accuracy = 100.00000
# 3.8262487e-26
#
# Train Accuracy = 100.00000
# EPOCH 331 ...
# Validation Accuracy = 100.00000
# 6.1796043e-27
#
# Train Accuracy = 100.00000
# EPOCH 341 ...
# Validation Accuracy = 100.00000
# 9.980403e-28
#
# Train Accuracy = 100.00000
# EPOCH 351 ...
# Validation Accuracy = 100.00000
# 1.6118906e-28
#
# Train Accuracy = 100.00000
# EPOCH 361 ...
# Validation Accuracy = 100.00000
# 2.6032927e-29
#
# Train Accuracy = 100.00000
# EPOCH 371 ...
# Validation Accuracy = 100.00000
# 4.2044616e-30
#
# Train Accuracy = 100.00000
# EPOCH 381 ...
# Validation Accuracy = 100.00000
# 6.7904387e-31
#
# Train Accuracy = 100.00000
# EPOCH 391 ...
# Validation Accuracy = 100.00000
# 1.0966934e-31
#
# Train Accuracy = 100.00000
# EPOCH 401 ...
# Validation Accuracy = 100.00000
# 1.771221e-32
#
# Train Accuracy = 100.00000
# EPOCH 411 ...
# Validation Accuracy = 100.00000
# 2.8606202e-33
#
# Train Accuracy = 100.00000
# EPOCH 421 ...
# Validation Accuracy = 100.00000
# 4.6200606e-34
#
# Train Accuracy = 100.00000
# EPOCH 431 ...
# Validation Accuracy = 100.00000
# 7.461655e-35
#
# Train Accuracy = 100.00000
# EPOCH 441 ...
# Validation Accuracy = 100.00000
# 1.2050985e-35
#
# Train Accuracy = 100.00000
# EPOCH 451 ...
# Validation Accuracy = 100.00000
# 1.946301e-36
#
# Train Accuracy = 100.00000
# EPOCH 461 ...
# Validation Accuracy = 100.00000
# 3.1433837e-37
#
# Train Accuracy = 100.00000
# EPOCH 471 ...
# Validation Accuracy = 100.00000
# 5.076739e-38
#
# Train Accuracy = 100.00000
# EPOCH 481 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 491 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 501 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 511 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 521 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 531 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 541 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 551 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 561 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 571 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 581 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 591 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 601 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 611 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 621 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 631 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 641 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 651 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 661 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 671 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 681 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 691 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 701 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 711 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 721 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 731 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 741 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 751 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 761 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 771 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 781 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 791 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 801 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 811 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 821 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 831 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 841 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 851 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 861 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 871 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 881 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 891 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 901 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 911 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 921 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 931 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 941 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 951 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 961 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 971 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 981 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 991 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1001 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1011 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1021 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1031 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1041 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1051 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1061 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1071 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1081 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1091 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1101 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1111 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1121 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1131 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1141 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1151 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1161 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1171 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1181 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1191 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1201 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1211 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1221 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1231 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1241 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1251 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1261 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1271 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1281 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1291 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1301 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1311 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1321 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1331 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1341 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1351 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1361 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1371 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1381 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1391 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1401 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1411 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1421 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1431 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1441 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1451 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1461 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1471 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1481 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1491 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1501 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1511 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1521 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1531 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1541 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1551 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1561 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1571 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1581 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1591 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1601 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1611 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1621 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1631 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1641 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1651 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1661 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1671 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1681 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1691 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1701 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1711 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1721 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1731 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1741 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1751 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1761 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1771 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1781 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1791 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1801 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1811 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1821 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1831 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1841 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1851 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1861 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1871 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1881 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1891 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1901 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1911 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1921 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1931 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1941 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1951 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1961 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1971 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1981 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 1991 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2001 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2011 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2021 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2031 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2041 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2051 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2061 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2071 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2081 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2091 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2101 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2111 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2121 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2131 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2141 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2151 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2161 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2171 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2181 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2191 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2201 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2211 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2221 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2231 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2241 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2251 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2261 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2271 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2281 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2291 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2301 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2311 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2321 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2331 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2341 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2351 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2361 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2371 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2381 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2391 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2401 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2411 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2421 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2431 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2441 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2451 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2461 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2471 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2481 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2491 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2501 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2511 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2521 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2531 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2541 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2551 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2561 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2571 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2581 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2591 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2601 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2611 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2621 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2631 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2641 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2651 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2661 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2671 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2681 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2691 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2701 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2711 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2721 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2731 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2741 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2751 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2761 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2771 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2781 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2791 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2801 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2811 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2821 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2831 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2841 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2851 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2861 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2871 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2881 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2891 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2901 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2911 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2921 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2931 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2941 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2951 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2961 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2971 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2981 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 2991 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3001 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3011 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3021 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3031 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3041 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3051 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3061 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3071 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3081 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3091 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3101 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3111 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3121 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3131 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3141 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3151 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3161 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3171 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3181 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3191 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3201 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3211 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3221 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3231 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3241 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3251 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3261 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3271 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3281 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3291 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3301 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3311 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3321 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3331 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3341 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3351 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Train Accuracy = 100.00000
# EPOCH 3361 ...
# Validation Accuracy = 100.00000
# 0.0
#
# Model saved

# %%
with tf.Session() as sess:
#     saver.restore(sess, tf.train.latest_checkpoint('.'))
    saver.restore(sess, './DNAAdamBasedAllPass')
#     saver.save(sess, './PendigitMomentBasedAllPass')  
    validation_accuracy = sess.run(accuracy*100, feed_dict={x: validation_data,y:validation_label_one_hot, is_testing: True})
    print("Validation Accuracy = {:.6f}".format(validation_accuracy))
# Out:
# INFO:tensorflow:Restoring parameters from ./DNAAdamBasedAllPass
# Validation Accuracy = 100.000000

# %%
# Without all pass
with tf.Session() as sess:
#     saver.restore(sess, tf.train.latest_checkpoint('.'))
    saver.restore(sess, './DNAAdamBasedAllPass')
    test_accuracy = sess.run(accuracy*100, feed_dict={x: test_data,y:test_label_one_hot, is_testing: True})
    print("Test Accuracy = {:.6f}".format(test_accuracy))
# Out:
# INFO:tensorflow:Restoring parameters from ./DNAAdamBasedAllPass
# Test Accuracy = 94.856659

# %%
# # Without all pass
# with tf.Session() as sess:
# #     saver.restore(sess, tf.train.latest_checkpoint('.'))
#     saver.restore(sess, './PendigitSGDBased')
#     test_accuracy = sess.run(accuracy*100, feed_dict={x: test_data,y:test_label_one_hot, is_testing: True})
#     print("Test Accuracy = {:.6f}".format(test_accuracy))

# %%
import scipy.io as sio

# %%
epochTrack = epoch_track
